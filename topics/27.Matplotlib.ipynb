# %%
import pandas as pd
import matplotlib.pyplot as plt
v=pd.read_csv(r"C:\Users\abine\OneDrive\Documents\python_1\cls work\student_database_updated1.csv")
v.plot()

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x=np.array([1,2,3,4,5])
y=np.array([5,4,3,2,1])

plt.plot(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt

x=np.array([1,2,3,4,5])
y=np.array([5,4,3,2,1])

plt.scatter(x,y)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([10,20,30,40])
y1=np.array([15,25,35,45])
plt.plot(x1,y1,marker=".")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10,11,12,34])

plt.plot(ypoints, marker = '*')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([10,20,30,40])
y1=np.array([15,25,35,45])
plt.plot(x1, linestyle="dotted")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
x1=np.array([10,20,30,40])
y1=np.array([15,25,35,45])
plt.xlabel("Range")
plt.ylabel("points")
plt.plot(x1,y1,marker=".")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])

plt.bar(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.barh(x,y)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([20,30,50,15])
mylab=["car","heavy ev","bike","bicycle"]
plt.pie(x,labels=mylab)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

x=np.array([20,30,50,15])
mylab=["car","heavy ev","bike","bicycle"]
explo=[0,0,0,0.1]
plt.pie(x,labels=mylab,explode=explo)
plt.show()

# %%
#subplot
import numpy as np
import matplotlib.pyplot as plt

x=np.array([20,30,50,15])
y=np.array([30,50,35,60])

plt.subplot(1,2,1)
plt.plot(x,y)

x=np.array([20,50,15])
y=np.array([30,50,35])
plt.subplot(1,2,2)
plt.plot(x,y)
plt.show()

# %%
#subplot
import numpy as np
import matplotlib.pyplot as plt

x=np.array([1,20,40])
y=np.array([1,20,1])

plt.subplot(1,3,1)
plt.plot(x,y)

x=np.array([20,50,15])
y=np.array([30,50,35])
plt.subplot(1,3,2)
plt.plot(x,y)

x=np.array([20,7,15])
y=np.array([30,5,35])
plt.subplot(1,3,3)
plt.plot(x,y)
plt.show()
